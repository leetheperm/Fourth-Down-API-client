# %%
from fourth_down_api import FourthDownEnvironment
from fourth_down_api.fourth_down_api_base import FourthDownApiBase
from fourth_down_api.api_json import ForthDownApiJson
from fourth_down_api.parameters import GameParameters, ScheduleParameters, ResultsParameters
import pandas as pd

# %%
api = ForthDownApiJson(FourthDownEnvironment.production)

# %%
teams = api.all_teams(verbose=True)
# Out:
# Request url: https://fourthdown.azurewebsites.net/api/teams
# Duration: 1.209s
# Status: 200

# %%
df = pd.read_json(teams)
df.head(10)
# Out:
#            city      name  abr conf    div      label         teamNameLabel
# 0     Baltimore    Ravens  BAL  AFC  North  AFC North      Baltimore Ravens
# 1    Cincinnati   Bengals  CIN  AFC  North  AFC North    Cincinnati Bengals
# 2     Cleveland    Browns  CLE  AFC  North  AFC North      Cleveland Browns
# 3    Pittsburgh  Steelers  PIT  AFC  North  AFC North   Pittsburgh Steelers
# 4       Buffalo     Bills  BUF  AFC   East   AFC East         Buffalo Bills
# 5         Miami  Dolphins  MIA  AFC   East   AFC East        Miami Dolphins
# 6   New England  Patriots   NE  AFC   East   AFC East  New England Patriots
# 7      New York      Jets  NYJ  AFC   East   AFC East         New York Jets
# 8       Houston    Texans  HOU  AFC  South  AFC South        Houston Texans
# 9  Indianapolis     Colts  IND  AFC  South  AFC South    Indianapolis Colts

# %%
schedule = api.schedule(ScheduleParameters(
    season=2021,
    team="LA"
),verbose=True)
schedule_df = pd.read_json(schedule)
schedule_df.head(5)
# Out:
# Request url: https://fourthdown.azurewebsites.net/api/schedule?Season=2021&Team=LA
# Duration: 1.084s
# Status: 200
#            gameId  season gameType  week              gameday weekday  \
# 0  2021_22_LA_CIN    2021       SB    22  2022-02-13T00:00:00  Sunday
# 1   2021_21_SF_LA    2021      CON    21  2022-01-30T00:00:00  Sunday
# 2   2021_20_LA_TB    2021      DIV    20  2022-01-23T00:00:00  Sunday
# 3  2021_19_ARI_LA    2021       WC    19  2022-01-17T00:00:00  Monday
# 4   2021_18_SF_LA    2021      REG    18  2022-01-09T00:00:00  Sunday
#
#   gametime awayTeam  awayScore homeTeam  ...  wind  awayQbId    homeQbId  \
# 0    18:30       LA         23      CIN  ...     0      dome  matrixturf
# 1    18:30       SF         17       LA  ...     1      dome  matrixturf
# 2    15:00       LA         30       TB  ...     0  outdoors       grass
# 3    20:15      ARI         11       LA  ...     1      dome  matrixturf
# 4    16:25       SF         27       LA  ...     1      dome  matrixturf
#
#    awaQbName  homeQbName   awayCoach   homeCoach           referee  \
# 0                         00-0026498  00-0036442  Matthew Stafford
# 1                         00-0031345  00-0026498   Jimmy Garoppolo
# 2         50          11  00-0026498  00-0019596  Matthew Stafford
# 3                         00-0035228  00-0026498      Kyler Murray
# 4                         00-0031345  00-0026498   Jimmy Garoppolo
#
#           stadiumId          stadium
# 0        Joe Burrow       Sean McVay
# 1  Matthew Stafford    Kyle Shanahan
# 2         Tom Brady       Sean McVay
# 3  Matthew Stafford  Kliff Kingsbury
# 4  Matthew Stafford    Kyle Shanahan
#
# [5 rows x 41 columns]

# %%
schedule_results = api.schedule_results(ResultsParameters(
    team="LA",
    opposition="CLE",
    game_offset=1,
    game_type="All"

),verbose=True)
schedule_df = pd.read_json(schedule)
schedule_df
# Out:
# Request url: https://fourthdown.azurewebsites.net/api/schedule/results?Team=LA&Opposition=CLE&gameOffset=1&gameType=All
# Duration: 0.442s
# Status: 200
#             gameId  season gameType  week              gameday   weekday  \
# 0   2021_22_LA_CIN    2021       SB    22  2022-02-13T00:00:00    Sunday
# 1    2021_21_SF_LA    2021      CON    21  2022-01-30T00:00:00    Sunday
# 2    2021_20_LA_TB    2021      DIV    20  2022-01-23T00:00:00    Sunday
# 3   2021_19_ARI_LA    2021       WC    19  2022-01-17T00:00:00    Monday
# 4    2021_18_SF_LA    2021      REG    18  2022-01-09T00:00:00    Sunday
# 5   2021_17_LA_BAL    2021      REG    17  2022-01-02T00:00:00    Sunday
# 6   2021_16_LA_MIN    2021      REG    16  2021-12-26T00:00:00    Sunday
# 7   2021_15_SEA_LA    2021      REG    15  2021-12-21T00:00:00   Tuesday
# 8   2021_14_LA_ARI    2021      REG    14  2021-12-13T00:00:00    Monday
# 9   2021_13_JAX_LA    2021      REG    13  2021-12-05T00:00:00    Sunday
# 10   2021_12_LA_GB    2021      REG    12  2021-11-28T00:00:00    Sunday
# 11   2021_10_LA_SF    2021      REG    10  2021-11-15T00:00:00    Monday
# 12  2021_09_TEN_LA    2021      REG     9  2021-11-07T00:00:00    Sunday
# 13  2021_08_LA_HOU    2021      REG     8  2021-10-31T00:00:00    Sunday
# 14  2021_07_DET_LA    2021      REG     7  2021-10-24T00:00:00    Sunday
# 15  2021_06_LA_NYG    2021      REG     6  2021-10-17T00:00:00    Sunday
# 16  2021_05_LA_SEA    2021      REG     5  2021-10-07T00:00:00  Thursday
# 17  2021_04_ARI_LA    2021      REG     4  2021-10-03T00:00:00    Sunday
# 18   2021_03_TB_LA    2021      REG     3  2021-09-26T00:00:00    Sunday
# 19  2021_02_LA_IND    2021      REG     2  2021-09-19T00:00:00    Sunday
# 20  2021_01_CHI_LA    2021      REG     1  2021-09-12T00:00:00    Sunday
#
#    gametime awayTeam  awayScore homeTeam  ...  wind  awayQbId    homeQbId  \
# 0     18:30       LA         23      CIN  ...     0      dome  matrixturf
# 1     18:30       SF         17       LA  ...     1      dome  matrixturf
# 2     15:00       LA         30       TB  ...     0  outdoors       grass
# 3     20:15      ARI         11       LA  ...     1      dome  matrixturf
# 4     16:25       SF         27       LA  ...     1      dome  matrixturf
# 5     13:00       LA         20      BAL  ...     0  outdoors       grass
# 6     13:00       LA         30      MIN  ...     0      dome   sportturf
# 7     19:00      SEA         10       LA  ...     1      dome  matrixturf
# 8     20:15       LA         30      ARI  ...     1      open      grass
# 9     16:05      JAX          7       LA  ...     0      dome  matrixturf
# 10    16:25       LA         28       GB  ...     0  outdoors      grass
# 11    20:15       LA         10       SF  ...     1  outdoors       grass
# 12    20:20      TEN         28       LA  ...     0      dome  matrixturf
# 13    13:00       LA         38      HOU  ...     0    closed   astroturf
# 14    16:05      DET         19       LA  ...     0      dome  matrixturf
# 15    13:00       LA         38      NYG  ...     0  outdoors   fieldturf
# 16    20:20       LA         26      SEA  ...     1  outdoors   fieldturf
# 17    16:05      ARI         37       LA  ...     1      dome  matrixturf
# 18    16:25       TB         24       LA  ...     0      dome  matrixturf
# 19    13:00       LA         27      IND  ...     0    closed   fieldturf
# 20    20:20      CHI         14       LA  ...     0      dome  matrixturf
#
#     awaQbName  homeQbName   awayCoach   homeCoach           referee  \
# 0                          00-0026498  00-0036442  Matthew Stafford
# 1                          00-0031345  00-0026498   Jimmy Garoppolo
# 2          50          11  00-0026498  00-0019596  Matthew Stafford
# 3                          00-0035228  00-0026498      Kyler Murray
# 4                          00-0031345  00-0026498   Jimmy Garoppolo
# 5          59           6  00-0026498  00-0035993  Matthew Stafford
# 6                          00-0026498  00-0029604  Matthew Stafford
# 7                          00-0029263  00-0026498    Russell Wilson
# 8                          00-0026498  00-0035228  Matthew Stafford
# 9                          00-0036971  00-0026498   Trevor Lawrence
# 10         37          14  00-0026498  00-0023459  Matthew Stafford
# 11         59           0  00-0026498  00-0031345  Matthew Stafford
# 12                         00-0029701  00-0026498    Ryan Tannehill
# 13                         00-0026498  00-0036898  Matthew Stafford
# 14                         00-0033106  00-0026498        Jared Goff
# 15         61          13  00-0026498  00-0035710  Matthew Stafford
# 16         56           8  00-0026498  00-0029263  Matthew Stafford
# 17                         00-0035228  00-0026498      Kyler Murray
# 18                         00-0019596  00-0026498         Tom Brady
# 19                         00-0026498  00-0032950  Matthew Stafford
# 20                         00-0027973  00-0026498       Andy Dalton
#
#            stadiumId          stadium
# 0         Joe Burrow       Sean McVay
# 1   Matthew Stafford    Kyle Shanahan
# 2          Tom Brady       Sean McVay
# 3   Matthew Stafford  Kliff Kingsbury
# 4   Matthew Stafford    Kyle Shanahan
# 5      Tyler Huntley       Sean McVay
# 6       Kirk Cousins       Sean McVay
# 7   Matthew Stafford     Pete Carroll
# 8       Kyler Murray       Sean McVay
# 9   Matthew Stafford      Urban Meyer
# 10     Aaron Rodgers       Sean McVay
# 11   Jimmy Garoppolo       Sean McVay
# 12  Matthew Stafford      Mike Vrabel
# 13       Davis Mills       Sean McVay
# 14  Matthew Stafford     Dan Campbell
# 15      Daniel Jones       Sean McVay
# 16    Russell Wilson       Sean McVay
# 17  Matthew Stafford  Kliff Kingsbury
# 18  Matthew Stafford     Bruce Arians
# 19      Carson Wentz       Sean McVay
# 20  Matthew Stafford        Matt Nagy
#
# [21 rows x 41 columns]

# %%
schedule = api.schedule(ScheduleParameters(),verbose=True)
pd.read_json(schedule)
# Out:
# Request url: https://fourthdown.azurewebsites.net/api/schedule
# Duration: 0.668s
# Status: 200
#               gameId  season gameType  week              gameday   weekday  \
# 0     2022_22_KC_PHI    2022       SB    22  2023-02-12T00:00:00    Sunday
# 1     2022_21_CIN_KC    2022      CON    21  2023-01-29T00:00:00    Sunday
# 2     2022_21_SF_PHI    2022      CON    21  2023-01-29T00:00:00    Sunday
# 3     2022_20_DAL_SF    2022      DIV    20  2023-01-22T00:00:00    Sunday
# 4    2022_20_CIN_BUF    2022      DIV    20  2023-01-22T00:00:00    Sunday
# ..               ...     ...      ...   ...                  ...       ...
# 279  2022_01_PIT_CIN    2022      REG     1  2022-09-11T00:00:00    Sunday
# 280   2022_01_SF_CHI    2022      REG     1  2022-09-11T00:00:00    Sunday
# 281  2022_01_CLE_CAR    2022      REG     1  2022-09-11T00:00:00    Sunday
# 282   2022_01_NO_ATL    2022      REG     1  2022-09-11T00:00:00    Sunday
# 283   2022_01_BUF_LA    2022      REG     1  2022-09-08T00:00:00  Thursday
#
#     gametime awayTeam  awayScore homeTeam  ...  wind  awayQbId    homeQbId  \
# 0      18:30       KC         38      PHI  ...     0    closed       grass
# 1      18:30      CIN         20       KC  ...     0  outdoors       grass
# 2      15:00       SF          7      PHI  ...     0  outdoors       grass
# 3      18:30      DAL         12       SF  ...     0  outdoors       grass
# 4      15:00      CIN         27      BUF  ...     0  outdoors      a_turf
# ..       ...      ...        ...      ...  ...   ...       ...         ...
# 279    13:00      PIT         23      CIN  ...     1  outdoors   fieldturf
# 280    13:00       SF         10      CHI  ...     0  outdoors       grass
# 281    13:00      CLE         26      CAR  ...     0  outdoors       grass
# 282    13:00       NO         27      ATL  ...     1    closed   fieldturf
# 283    20:20      BUF         31       LA  ...     0      dome  matrixturf
#
#      awaQbName  homeQbName   awayCoach   homeCoach          referee  \
# 0                           00-0033873  00-0036389  Patrick Mahomes
# 1           22          13  00-0036442  00-0033873       Joe Burrow
# 2           52          14  00-0037834  00-0036389      Brock Purdy
# 3           55          19  00-0033077  00-0037834     Dak Prescott
# 4           32           4  00-0036442  00-0034857       Joe Burrow
# ..         ...         ...         ...         ...              ...
# 279                         00-0033869  00-0036442   Mitch Trubisky
# 280                         00-0037012  00-0036945       Trey Lance
# 281                         00-0033119  00-0034855  Jacoby Brissett
# 282                         00-0031503  00-0032268   Jameis Winston
# 283                         00-0034857  00-0026498       Josh Allen
#
#             stadiumId          stadium
# 0         Jalen Hurts        Andy Reid
# 1     Patrick Mahomes       Zac Taylor
# 2         Jalen Hurts    Kyle Shanahan
# 3         Brock Purdy    Mike McCarthy
# 4          Josh Allen       Zac Taylor
# ..                ...              ...
# 279        Joe Burrow      Mike Tomlin
# 280     Justin Fields    Kyle Shanahan
# 281    Baker Mayfield  Kevin Stefanski
# 282    Marcus Mariota     Dennis Allen
# 283  Matthew Stafford   Sean McDermott
#
# [284 rows x 41 columns]
